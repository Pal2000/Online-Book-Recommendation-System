# %% [markdown]
# # Book Recommendation System

# %% [markdown]
# First download the csv data set by clicking this link
# Dataset url: http://www2.informatik.uni-freiburg.de/~cziegler/BX/
#
# I have provided the detail for each part of code for better understanding.

# %%
#details:- Reading the necessary features
# BX-Books.csv,BX-Users.csv, BX-Book-Ratings.csv these are the files that we have get from data set. And these are related to
#each other like ISBN is common to 1 and 3 file and userID is common to 2 and 3 file.
# In this part of code we are just reading the data.
# ISBN->> unique identity for the books
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
books = pd.read_csv('BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")
books.columns = ['ISBN', 'bookTitle', 'bookAuthor', 'yearOfPublication', 'publisher', 'imageUrlS', 'imageUrlM', 'imageUrlL']
users = pd.read_csv('BX-Users.csv', sep=';', error_bad_lines=False, encoding="latin-1")
users.columns = ['userID', 'Location', 'Age']
ratings = pd.read_csv('BX-Book-Ratings.csv', sep=';', error_bad_lines=False, encoding="latin-1")
ratings.columns = ['userID', 'ISBN', 'bookRating']
# Out:
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# b'Skipping line 209388: expected 8 fields, saw 9\nSkipping line 220626: expected 8 fields, saw 9\nSkipping line 227933: expected 8 fields, saw 11\nSkipping line 228957: expected 8 fields, saw 10\nSkipping line 245933: expected 8 fields, saw 9\nSkipping line 251296: expected 8 fields, saw 9\nSkipping line 259941: expected 8 fields, saw 9\nSkipping line 261529: expected 8 fields, saw 9\n'
# ...

# %%
## now printing the total count how many ratings are present
print(ratings.shape)
print(list(ratings.columns))
# Out:
# (527556, 3)
# ['userID', 'ISBN', 'bookRating']

# %%
## for demostration we plot a graph for rating
plt.rc("font", size=15)
ratings.bookRating.value_counts(sort=False).plot(kind='bar')
plt.title('Rating Distribution\n')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.savefig('system1.png', bbox_inches='tight')
plt.show()

# %%
# to show details of books
print(books.shape)
print(list(books.columns))
# Out:
# (271360, 8)
# ['ISBN', 'bookTitle', 'bookAuthor', 'yearOfPublication', 'publisher', 'imageUrlS', 'imageUrlM', 'imageUrlL']

# %%
# user details for recpommendation or who give ratings to the books
print(users.shape)
print(list(users.columns))
# Out:
# (278858, 3)
# ['userID', 'Location', 'Age']

# %%
#  This graph gives the information that which age group of people give how much ratings
users.Age.hist(bins=[0, 10, 20, 30, 40, 50, 100])
plt.title('Age Distribution\n')
plt.xlabel('Age')
plt.ylabel('Count')
plt.savefig('system2.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Book Recommendation Based on Rating

# %%
# firstly showing the records of all ratings
# we have created a Rating dataframe group by ISBN and rating Counts
# sort the data frame
rating_count = pd.DataFrame(ratings.groupby('ISBN')['bookRating'].count())
rating_count.sort_values('bookRating', ascending=False).head()
# Out:
#             bookRating
# ISBN
# 0971880107        2502
# 0316666343        1295
# 0385504209         883
# 0060928336         732
# 0312195516         723

# %% [markdown]
#  Now from the output of above code we found that ist book recommended by most of the people so we consider that this book is highly recommended on the basis of rating given by the people.

# %%
## To show the details of recommended books
# this is final recommendation
most_rated_books = pd.DataFrame(['0971880107', '0316666343', '0385504209', '0060928336', '0312195516'], index=np.arange(5), columns = ['ISBN'])
most_rated_books_summary = pd.merge(most_rated_books, books, on='ISBN')
most_rated_books_summary
# in this we are merging the two data set most_rated_books and books on the basis of ISBN to show the information
# Out:
#          ISBN                                        bookTitle     bookAuthor  \
# 0  0971880107                                      Wild Animus   Rich Shapero
# 1  0316666343                        The Lovely Bones: A Novel   Alice Sebold
# 2  0385504209                                The Da Vinci Code      Dan Brown
# 3  0060928336  Divine Secrets of the Ya-Ya Sisterhood: A Novel  Rebecca Wells
# 4  0312195516              The Red Tent (Bestselling Backlist)  Anita Diamant
#
#   yearOfPublication      publisher  \
# 0              2004        Too Far
# 1              2002  Little, Brown
# 2              2003      Doubleday
# 3              1997      Perennial
# 4              1998    Picador USA
#
#                                            imageUrlS  \
# 0  http://images.amazon.com/images/P/0971880107.0...
# 1  http://images.amazon.com/images/P/0316666343.0...
# 2  http://images.amazon.com/images/P/0385504209.0...
# 3  http://images.amazon.com/images/P/0060928336.0...
# ...

# %% [markdown]
# ### Recommendation Based on Correlation

# %% [markdown]
# The disadvantage of Book recommendation based on rating is that when only few people recommended the book and larger no. of
# people are not recommended the particular book. But rating count of these people who are against the book is more than who
# perfer the book so in that case recommendation based on ratings will not give the correct result.
# So one of the best method to resolve this problem is to use Pearson'R correlation.
# We use Pearsons’R correlation coefficient to measure the linear correlation between two variables, in our case, the ratings for two books.
#
# First, we need to find out the average rating, and the number of ratings each book received.

# %%
average_rating = pd.DataFrame(ratings.groupby('ISBN')['bookRating'].mean())
average_rating['ratingCount'] = pd.DataFrame(ratings.groupby('ISBN')['bookRating'].count())
average_rating.sort_values('ratingCount', ascending=False).head()
# Out:
#             bookRating  ratingCount
# ISBN
# 0971880107    1.019584         2502
# 0316666343    4.468726         1295
# 0385504209    4.652322          883
# 0060928336    3.448087          732
# 0312195516    4.334716          723

# %% [markdown]
# Observations: In this data set, the book that received the most rating counts was not highly rated at all. As a result, if we
# were to use recommendations based on rating counts, we would definitely make mistakes here. So, we need to have a better system.

# %% [markdown]
# To ensure statistical significance, users with less than 200 ratings, and books with less than 100 ratings are excluded.¶

# %%
# we are excluding that books whose ratings are less than 100 and user with less than 200 ratings
counts1 = ratings['userID'].value_counts()
ratings = ratings[ratings['userID'].isin(counts1[counts1 >= 200].index)]
counts = ratings['bookRating'].value_counts()
ratings = ratings[ratings['bookRating'].isin(counts[counts >= 100].index)]

# %% [markdown]
# #### Rating matrix

# %% [markdown]
# We convert the ratings table to a 2D matrix. The matrix will be sparse because not every user rated every book.

# %%
# NAN indicates whether a person given a rating or not; if not then it is shown as NAN
ratings_pivot = ratings.pivot(index='userID', columns='ISBN').bookRating
userID = ratings_pivot.index
ISBN = ratings_pivot.columns
print(ratings_pivot.shape)
ratings_pivot.head()
# Out:
# (905, 207699)
# ISBN     0330299891   0375404120   0586045007   9022906116   9032803328  \
# userID
# 254             NaN          NaN          NaN          NaN          NaN
# 2276            NaN          NaN          NaN          NaN          NaN
# 2766            NaN          NaN          NaN          NaN          NaN
# 2977            NaN          NaN          NaN          NaN          NaN
# 3363            NaN          NaN          NaN          NaN          NaN
#
# ISBN     9044922564   9044922572   9044922718   9044923161   904492401X  ...  \
# userID                                                                   ...
# 254             NaN          NaN          NaN          NaN          NaN  ...
# 2276            NaN          NaN          NaN          NaN          NaN  ...
# 2766            NaN          NaN          NaN          NaN          NaN  ...
# 2977            NaN          NaN          NaN          NaN          NaN  ...
# ...

# %%
# take one ISBN number from above pivot table and correlate this rating of this book whose rating is (0316666343) with other books
bones_ratings = ratings_pivot['0316666343']
similar_to_bones = ratings_pivot.corrwith(bones_ratings) # corrwith() find relation with 1 data set to another dataset
corr_bones = pd.DataFrame(similar_to_bones, columns=['pearsonR']) # this gives pearson relation ranges from 0 to 1
# more closer to 1 more that book is correlated
corr_bones.dropna(inplace=True)  ## dropping the all NAN values and keep just those ratings which are correlated
corr_summary = corr_bones.join(average_rating['ratingCount'])  ## join the correlated data with average rating
corr_summary[corr_summary['ratingCount']>=300].sort_values('pearsonR', ascending=False).head(10) ## sort them
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#             pearsonR  ratingCount
# ISBN
# 0316666343  1.000000         1295
# 0312291639  0.471872          354
# 0316601950  0.434248          568
# 0446610038  0.429712          391
# 0446672211  0.421478          585
# 0385265700  0.351635          319
# 0345342968  0.316922          321
# 0060930535  0.309860          494
# 0375707972  0.308145          354
# 0684872153  0.272480          326

# %% [markdown]
# We obtained the books’ ISBNs, but we need to find out the titles of the books to see whether they make sense.

# %%
## shows that details of recommended books by merging the correlated books with original book data set
books_corr_to_bones = pd.DataFrame(['0312291639', '0316601950', '0446610038', '0446672211', '0385265700', '0345342968', '0060930535', '0375707972', '0684872153'], 
                                  index=np.arange(9), columns=['ISBN'])
corr_books = pd.merge(books_corr_to_bones, books, on='ISBN')
corr_books
# Out:
#          ISBN                                          bookTitle  \
# 0  0312291639                         The Nanny Diaries: A Novel
# 1  0316601950                         The Pilot's Wife : A Novel
# 2  0446610038                                1st to Die: A Novel
# 3  0446672211  Where the Heart Is (Oprah's Book Club (Paperba...
# 4  0385265700   The Book of Ruth (Oprah's Book Club (Paperback))
# 5  0345342968                                     Fahrenheit 451
# 6  0060930535                      The Poisonwood Bible: A Novel
# 7  0375707972                                         The Reader
# 8  0684872153                    Angela's Ashes (MMP) : A Memoir
#
#            bookAuthor yearOfPublication             publisher  \
# 0     Emma McLaughlin              2003  St. Martin's Griffin
# 1        Anita Shreve              1999        Back Bay Books
# 2     James Patterson              2002         Warner Vision
# 3        Billie Letts              1998          Warner Books
# ...
